# %%
import sagemaker
import torch
from sagemaker.pytorch import PyTorch, PyTorchModel

# %%
USE_GPU = False

TRAIN_DEVICE = 'ml.g4dn.xlarge' if USE_GPI else 'ml.md5.large'
DEPLOY_DEVICE = 'ml.m5.large'
